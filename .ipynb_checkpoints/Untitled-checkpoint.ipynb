# %%
import pandas as pd

# %%
colnames = ["UID", "Artist", "Song", "Lyrics"]
df = pd.read_csv('./MOODSIC_LYRICS_DATASET_SORTED.csv', skiprows=98972, nrows=49486, header=0, names=colnames)

# %%
df
# Out:
#            UID          Artist                         Song  \
# 0      S098972  billie holiday    you re too lovely to last
# 1      S098973  billie holiday        you showed me the way
# 2      S098974  billie holiday     you took advantage of me
# 3      S098975  billie holiday  you turned the tables on me
# 4      S098976  billie holiday               you ve changed
# ...        ...             ...                          ...
# 49481  S148453    busta rhymes                 rock cocaine
# 49482  S148454    busta rhymes       rough around the edges
# 49483  S148455    busta rhymes         rumble in the jungle
# 49484  S148456    busta rhymes                run for cover
# 49485  S148457    busta rhymes               salute da gods
#
#                                                   Lyrics
# 0      Teddy mcrae / c. beal / e. fraser\nJust when y...
# 1      You showed me the way\nWhen I was someone in d...
# 2      I'm a sentimental sap, that's all,\nwhat's the...
# ...
